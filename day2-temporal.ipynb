# %% [markdown]
# # Données temporelles
# - conforme ISO 8601
# - dictionnaire IANA

# %%
from datetime import (
    datetime, date, time,   # non conformes PEP 8
    timedelta, 
    MINYEAR, MAXYEAR
 ) 
from zoneinfo import (
    ZoneInfo, ZoneInfoNotFoundError,
    available_timezones # conforme PEP 8
)
import re
import locale

# %%
# date heure locale
dt1 = datetime.now() # methode de classe
print(dt1)
dt1
# Out:
# 2026-07-01 14:17:44.526117
# datetime.datetime(2026, 7, 1, 14, 17, 44, 526117)

# %%
print('années :', MINYEAR, 'à',  MAXYEAR)
# Out:
# années : 1 à 9999

# %%
# timezones avec le dictionnaire IANA
from zoneinfo import ZoneInfoNotFoundError


for tz_str in (
    'Asia/Tokyo', 'Europe/Lisbon', 'Pacific/Tahiti', 
    'US/Hawaii', 'Pacific/Honolulu',
    'Asia/Singapore', 
    'America/Montreal',
    'Asia/Kolkata',
    'Asia/Istanbul', 'Europe/Istanbul',
    'Europe/Pau',
):  #  Istanbul
    try:
        tz = ZoneInfo(tz_str)
        dt = datetime.now(tz=tz) # methode de classe
        print(f"- tz {tz}: {dt}")
    except ZoneInfoNotFoundError as ex:
        print(f"- tz {tz_str} inconnue: {ex}")
# Out:
# - tz Asia/Tokyo: 2026-07-01 21:57:25.003894+09:00
# - tz Europe/Lisbon: 2026-07-01 13:57:25.003894+01:00
# - tz Pacific/Tahiti: 2026-07-01 02:57:25.004894-10:00
# - tz US/Hawaii: 2026-07-01 02:57:25.004894-10:00
# - tz Pacific/Honolulu: 2026-07-01 02:57:25.005894-10:00
# - tz Asia/Singapore: 2026-07-01 20:57:25.005894+08:00
# - tz America/Montreal: 2026-07-01 08:57:25.006893-04:00
# - tz Asia/Kolkata: 2026-07-01 18:27:25.006893+05:30
# - tz Asia/Istanbul: 2026-07-01 15:57:25.006893+03:00
# - tz Europe/Istanbul: 2026-07-01 15:57:25.007893+03:00
# - tz Europe/Pau inconnue: 'No time zone found with key Europe/Pau'

# %%
timezones = available_timezones()
timezones
# Out:
# {'Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
[tz for tz in timezones if 'Lisbon' in tz]
# Out:
# ['Europe/Lisbon']

# %%
[tz for tz in timezones if re.search(r'/lisbo', tz, flags=re.I)]
# Out:
# ['Europe/Lisbon']

# %%
[tz for tz in timezones if re.search(r'india.*/', tz, flags=re.I)]
# Out:
# ['Indian/Reunion',
#  'America/Indiana/Winamac',
#  'Indian/Maldives',
#  'America/Indiana/Vevay',
#  'America/Indiana/Knox',
#  'Indian/Mauritius',
#  'Indian/Antananarivo',
#  'Indian/Kerguelen',
#  'Indian/Mayotte',
#  'Indian/Mahe',
#  'Indian/Christmas',
#  'America/Indiana/Marengo',
#  'America/Indiana/Petersburg',
#  'Indian/Cocos',
#  'Indian/Comoro',
#  'America/Indiana/Tell_City',
#  'America/Indiana/Vincennes',
#  'Indian/Chagos',
#  'America/Indiana/Indianapolis']

# %%
dt = datetime.now()
d = date.today()
t = dt.time()
print(f"Date heure système: {dt:%H:%M le %d/%m/%Y}")
print(f"Date heure système: {dt:%H:%M le %A %d %B %Y}")
print(f"Date système: {d:%d/%m/%Y}")
print(f"Heure système: {t:%H:%M:%S}")
# Out:
# Date heure système: 15:06 le 01/07/2026
# Date heure système: 15:06 le Wednesday 01 July 2026
# Date système: 01/07/2026
# Heure système: 15:06:46

# %%
locale.getlocale(locale.LC_TIME)
# Out:
# (None, None)

# %%
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8')
locale.getlocale(locale.LC_TIME)
# Out:
# ('fr_FR', 'UTF-8')

# %%
print(f"Date heure système: {dt:%H:%M le %A %d %B %Y}")
# Out:
# Date heure système: 15:06 le mercredi 01 juillet 2026

# %%
words_fr = ['RANCŒUR', 'rançon', 'œuf', 'œuvre', 'ouvrage', 'Zèbre', 'été', 'étuve', 'étage', 'rancard', 'arbre']

# %%
words_fr.sort()
words_fr
# Out:
# ['RANCŒUR',
#  'Zèbre',
#  'arbre',
#  'ouvrage',
#  'rancard',
#  'rançon',
#  'étage',
#  'étuve',
#  'été',
#  'œuf',
#  'œuvre']

# %%
words_fr.sort(key=locale.strxfrm)
words_fr
# Out:
# ['arbre',
#  'étage',
#  'été',
#  'étuve',
#  'œuf',
#  'œuvre',
#  'ouvrage',
#  'rancard',
#  'RANCŒUR',
#  'rançon',
#  'Zèbre']

# %%
words2 = sorted(words_fr, key=locale.strxfrm)
words2
# Out:
# ['arbre',
#  'étage',
#  'été',
#  'étuve',
#  'œuf',
#  'œuvre',
#  'ouvrage',
#  'rancard',
#  'RANCŒUR',
#  'rançon',
#  'Zèbre']

# %%
locale.strxfrm('RANCŒUR')
# Out:
# '\x0e\x8a\x0e\x02\x0ep\x0e\n\x0e|\x0e!\x0e\x9f\x0e\x8a\x01\x01\x12\x12\x12\x12\x12\x12\x12\x12\x01\x01'

# %%
# méthode de classes
dt1 = datetime.now()
dt2 = datetime.strptime('29/02/2028 04h30', '%d/%m/%Y %Hh%M')
# constructeur (1 seul)
dt3 = datetime(2000, 2, 29, 13, 33)

for dt in dt1, dt2, dt3:
    print(dt)
    # attributs/propriétés
    print(dt.year)
    print(dt.month)
    print(dt.day)
    print(dt.hour)
    print(dt.minute)
    print(dt.second)
    # méthodes (objet)
    print(dt.date())
    print(dt.time())
    print()
# Out:
# 2026-07-01 15:58:09.183860
# 2026
# 7
# 1
# 15
# 58
# 9
# 2026-07-01
# 15:58:09.183860
#
# 2028-02-29 04:30:00
# 2028
# 2
# 29
# 4
# 30
# 0
# 2028-02-29
# 04:30:00
#
# 2000-02-29 13:33:00
# 2000
# 2
# 29
# 13
# 33
# 0
# 2000-02-29
# 13:33:00
