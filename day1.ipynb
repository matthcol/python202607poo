# %% [markdown]
# # Python
# Apprendre Python avec un notebook, c'est plus interactif.

# %%
# lib standard python
import json
# scientific python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Exemple Introduction

# %%
data = np.random.normal(10.0, 2.5, 1_000_000)
data
# Out:
# array([ 8.00457102,  9.7692532 , 11.73018214, ..., 11.03371106,
#         9.86568887, 15.18201957], shape=(1000000,))

# %%
_ = plt.hist(data, bins=1000)

# %%
data.mean(), data.std()
# Out:
# (np.float64(9.998794297309418), np.float64(2.4983153361206423))

# %% [markdown]
# ## Données Builtins
# Simples:
# - float
# - int
# - complex
# - str (Unicode)
# - bool
# - bytes
# - None
#
# Conteneurs:
# - list, tuple
# - dict
# - set

# %%
x = 1E308
x, 2*x, type(x)
# Out:
# (1e+308, inf, float)

# %%
nb = 
nb * 2
# Out:
# 

# %%
city1 = "L'Haÿ-les-Roses"
word_fr = "cœur"
city2 = "東京"
sentence = f"I ❤️ both {city1} and {city2} with all my {word_fr}"  # f-string
sentence
# Out:
# "I ❤️ both L'Haÿ-les-Roses and 東京 with all my cœur"

# %%
len(city2) == 2
# Out:
# True

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# ### Fonctions natives

# %%
print(city2) # calls str
city2  # calls repr
# Out:
# 東京
# '東京'

# %%
print(data)
data
# Out:
# [ 8.00457102  9.7692532  11.73018214 ... 11.03371106  9.86568887
#  15.18201957]
# array([ 8.00457102,  9.7692532 , 11.73018214, ..., 11.03371106,
#         9.86568887, 15.18201957], shape=(1000000,))

# %%
print(str(city2))
print(repr(city2))
# Out:
# 東京
# '東京'

# %%
print(len(city1))
print(len(data))
# print(len(None)) # TypeError: object of type 'NoneType' has no len()
# print(len(x)) # TypeError: object of type 'float' has no len()
# print(len(nb)) # TypeError: object of type 'int' has no len()
# Out:
# 15
# 1000000

# %%
print(bool(None))
print(not None)
print(None or True)
print(bool(city2))
print(bool(""))
print(bool(0))
print(bool([]))
# Out:
# False
# True
# True
# True
# False
# False
# False

# %%
nb_text = "123"
nb = int(nb_text) # base=10 par défaut
nb
# Out:
# 123

# %%
nb_text = "aa12ffbc"
nb = int(nb_text, base=16)
nb
# Out:
# 2853371836

# %%
int(nb_text, 16)
# Out:
# 2853371836

# %%
# TypeError: 'x' is an invalid keyword argument for int()
# int(x=nb_text, base=16)

# %%
print(city1, city2, word_fr)
print()
print(city1, city2, word_fr, sep=", ")
print(city1, city2, sep=" -> ", end=". ")
print("Arrêt pour manger.")
# Out:
# L'Haÿ-les-Roses 東京 cœur
#
# L'Haÿ-les-Roses, 東京, cœur
# L'Haÿ-les-Roses -> 東京. Arrêt pour manger.

# %%
sep = " -> "
print(city1, city2, sep=sep)
print(city1.upper(), city2.upper(), sep=sep)
# Out:
# L'Haÿ-les-Roses -> 東京
# L'HAŸ-LES-ROSES -> 東京

# %% [markdown]
# ### Conteneurs
# Builtin collections:
# - list: [v1, v2], en général homogène (car modifiable)
# - tuple: (v1, v2) ou sans v1, v2 ; non modifiable (peut être hétérogène)
# - dict: {k1: v1, k2: v2}
# - set: {v1, v2}

# %%
cities = [
# cities: list[str] = [
    'Toulouse',
    'Bordeaux', 
    'Hanoï',
    'Pibrac',
    'Saillagouse', 
    'Belfast',
    'Crampagna',
    'New-York',
    'Pau'
]

# %%
type(cities), len(cities)
# Out:
# (list, 9)

# %%
# list_city_pop: list[tuple[str, int]] = [
list_city_pop = [
    ('Toulouse', 500_000),
    ('Bordeaux', 300_000), 
    ('Hanoï', 9_000_000),
    ('Pibrac',7_000),
    ('Saillagouse', 1_200), 
    ('Belfast', 640_000),
    ('Crampagna', 110),
    ('New-York', 20_000_000),
    ('Pau', 77_000)
]

# %%
print(cities[0]) # 1er
print(cities[-1]) # dernier, i.e. len() - 1
# print(cities[9]) # IndexError: list index out of range

print(list_city_pop[0])
print(list_city_pop[-1])

print(list_city_pop[0][0])
# Out:
# Toulouse
# Pau
# ('Toulouse', 500000)
# ('Pau', 77000)
# Toulouse

# %%
city2[0]
# Out:
# '東'

# %%
# city2[0] = 'A' # TypeError: 'str' object does not support item assignment
# list_city_pop[0][1] += 1 # TypeError: 'tuple' object does not support item assignment
list_city_pop[0] = (list_city_pop[0][0], list_city_pop[0][1] + 1)
list_city_pop[0]
# Out:
# ('Toulouse', 500001)

# %%
def incr_city(list_city_pop: list[tuple[str, int]], index: int, delta: int) -> None:
    name, pop = list_city_pop[index]
    list_city_pop[index] = (name, pop + delta)

# %%
r = incr_city(list_city_pop, 0, 10_523)
assert r is None
list_city_pop[0]
# Out:
# ('Toulouse', 510524)

# %%
cities.append('Paris')
cities.extend(['Marseille', 'Lille'])
# cities.extend('Tours') # Attention ! ajoute les lettres 1 à 1
cities
# Out:
# ['Toulouse',
#  'Bordeaux',
#  'Hanoï',
#  'Pibrac',
#  'Saillagouse',
#  'Belfast',
#  'Crampagna',
#  'New-York',
#  'Pau',
#  'Paris',
#  'Marseille',
#  'Lille']

# %%
print(city1[:5])  # 5 premiers: de l'index 0 à 4
print(city1[5:10])
print(city1[10:])

print(city1[-5:]) # 5 derniers
# Out:
# L'Haÿ
# -les-
# Roses
# Roses

# %%
print(cities[3])
print(cities[3][-5:])
# Out:
# Pibrac
# ibrac

# %%
print(cities[100:])
# Out:
# []

# %%
data[::10_000]
# Out:
# array([ 8.00457102,  7.67401653,  5.51690855,  9.18090343, 11.06060068,
#         7.29291287,  7.7625648 , 12.33325959, 10.16578852,  8.44247009,
#        11.45502205,  9.53622058,  8.48218336,  6.5699258 ,  8.79825884,
#         8.51644557,  3.19078868, 12.7965484 , 13.62702082, 10.14125386,
#         8.79641778, 11.07999472,  8.49826222, 11.99707677,  9.01652381,
#        11.29096208,  7.28379795,  7.12122806,  6.19667703,  8.62297805,
#        16.10369634, 13.21413298,  5.64368346, 11.95103673, 11.68724891,
#        13.37512155,  9.92795056,  7.43743505,  6.11583275, 12.51759516,
#        12.27937405,  6.3048859 , 12.06764529, 10.10281893, 11.041705  ,
#         8.85367221,  8.57305593, 10.89149818,  9.23205401,  6.59141769,
#        10.45393877, 14.5215142 , 10.34222793, 12.29972903, 15.11729631,
#         9.5888151 , 13.66414388,  9.10778451,  9.040809  , 10.8862468 ,
#         8.28703616, 12.17319348, 10.44210562,  7.63015394, 10.38586857,
#         8.43662974,  8.88836722,  9.77670396, 12.04716887,  9.01354886,
#        10.02311317,  5.79422245, 12.81160842,  9.85354417,  8.9768821 ,
#         8.98008037,  7.70448364, 13.89196925, 11.5231756 , 12.74019814,
#         9.19753793, 10.48949106, 13.32454176, 12.96504576, 10.36188427,
#        11.26738943,  6.03938138, 12.54144757, 10.43612306, 10.82803996,
#        13.16450616,  6.93923974,  8.88280909,  8.10053545, 10.21153304,
#        11.56890732,  7.01132849, 11.54382536, 11.51256254,  7.8792093 ])

# %%
city1[::-1]
# Out:
# "sesoR-sel-ÿaH'L"

# %%
def is_palindrome(word: str) -> bool:
    return word.lower() == word[::-1].lower()

# %%
assert is_palindrome('kayak')
assert is_palindrome('Kayak')
assert not is_palindrome(city1)

# %%
print(len(city1))
print(len(cities))
print(len(list_city_pop[0]))
print(len(list_city_pop[0][0]))
# print(len(list_city_pop[0][1])) #TypeError: object of type 'int' has no len()
# Out:
# 15
# 12
# 2
# 8

# %%
print(list_city_pop[0])
print(list_city_pop[0][0])
print(list_city_pop[0][0][2])
# Out:
# ('Toulouse', 510524)
# Toulouse
# u

# %%
for city in cities:
    print(city)
# Out:
# Toulouse
# Bordeaux
# Hanoï
# Pibrac
# Saillagouse
# Belfast
# Crampagna
# New-York
# Pau
# Paris
# Marseille
# Lille

# %%
# TypeError: 'int' object is not iterable
# for digit in nb:
    # print(digit)

# %%
for l in city1:
    print(l, l.upper(), sep=' -> ')
# Out:
# L -> L
# ' -> '
# H -> H
# a -> A
# ÿ -> Ÿ
# - -> -
# l -> L
# e -> E
# s -> S
# - -> -
# R -> R
# o -> O
# s -> S
# e -> E
# s -> S

# %%
for i in range(len(cities)):
    city = cities[i]
    print(i, city)
# Out:
# 0 Toulouse
# 1 Bordeaux
# 2 Hanoï
# 3 Pibrac
# 4 Saillagouse
# 5 Belfast
# 6 Crampagna
# 7 New-York
# 8 Pau
# 9 Paris
# 10 Marseille
# 11 Lille

# %%
for i, city in enumerate(cities):
    print(f"{i} - {city}")
# Out:
# 0 - Toulouse
# 1 - Bordeaux
# 2 - Hanoï
# 3 - Pibrac
# 4 - Saillagouse
# 5 - Belfast
# 6 - Crampagna
# 7 - New-York
# 8 - Pau
# 9 - Paris
# 10 - Marseille
# 11 - Lille

# %%
for i, city in enumerate(cities, start=1):
    print(f"{i:02d} - {city}")
# Out:
# 01 - Toulouse
# 02 - Bordeaux
# 03 - Hanoï
# 04 - Pibrac
# 05 - Saillagouse
# 06 - Belfast
# 07 - Crampagna
# 08 - New-York
# 09 - Pau
# 10 - Paris
# 11 - Marseille
# 12 - Lille

# %% [markdown]
# ### Exercice: les villes qui comment par B

# %%
for city in cities:
    if city.strip().lower().startswith('b'):
        print(city)
# Out:
# Bordeaux
# Belfast

# %%
cities_b = []
for city in cities:
    if city.strip().lower().startswith('b'):
        cities_b.append(city)
cities_b
# Out:
# ['Bordeaux', 'Belfast']

# %%
cities.extend(['bruxelles', '  bourges ', '\tblagnac\t\t\n\r'])

# %%
[city for city in cities if city.strip().lower().startswith('b')]
# Out:
# ['Bordeaux', 'Belfast', 'bruxelles', '  bourges ', '\tblagnac\t\t\n\r']

# %%
[city.strip().lower() for city in cities]
# Out:
# ['toulouse',
#  'bordeaux',
#  'hanoï',
#  'pibrac',
#  'saillagouse',
#  'belfast',
#  'crampagna',
#  'new-york',
#  'pau',
#  'paris',
#  'marseille',
#  'lille',
#  'bruxelles',
#  'bourges',
#  'blagnac']

# %%
cities_filtered = [
    city_n for city_n in (
        city.strip().lower() for city in cities
    ) if city_n.startswith('b')
]
cities_filtered
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
numbers = [12, 23, 67, 43]
[n**2 + 1 for n in numbers]
# Out:
# [145, 530, 4490, 1850]

# %%
[n**2 + 1 for n in numbers if n % 2 == 1]
# Out:
# [530, 4490, 1850]

# %%
g = (n**2 + 1 for n in numbers if n % 2 == 1)
g
# Out:
# <generator object <genexpr> at 0x0000016D39B941E0>

# %%
sum(g)
# Out:
# 6870

# %%
list(
    filter(
        lambda city_n: city_n.startswith('b'),
        map(
            lambda city: city.strip().lower(),
            cities
        )
    )
)
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
cities_b = []
for city in cities:
    city_n = city.strip().lower()
    if city_n.startswith('b'):
        cities_b.append(city_n)
cities_b
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
f = 'λ x: x**2 + 1'
f
# Out:
# 'λ x: x**2 + 1'

# %%
f2 = f.replace('λ', 'lambda')
f2
# Out:
# 'lambda x: x**2 + 1'

# %%
f3 = eval(f2)
f3
# Out:
# <function __main__.<lambda>(x)>

# %%
f3(3)
# Out:
# 10

# %% [markdown]
# ## Villes de plus de 100 000 habitants

# %%
f = open('data/villes100k.json', encoding='UTF-8')
f
# Out:
# <_io.TextIOWrapper name='data/villes100k.json' mode='r' encoding='UTF-8'>

# %%
data = list(f)
data
# Out:
# ['[\n',
#  '   {\n',
#  '      "nom_standard":"Nice",\n',
#  '      "nom_sans_pronom":"Nice",\n',
#  '      "dep_code":"06",\n',
#  '      "dep_nom":"Alpes-Maritimes",\n',
#  '      "code_postal":"06000",\n',
#  '      "population":348085,\n',
#  '      "superficie_km2":74\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Aix-en-Provence",\n',
#  '      "nom_sans_pronom":"Aix-en-Provence",\n',
#  '      "dep_code":"13",\n',
#  '      "dep_nom":"Bouches-du-Rhône",\n',
#  '      "code_postal":"13100",\n',
#  '      "population":147478,\n',
#  '      "superficie_km2":188\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Marseille",\n',
#  '      "nom_sans_pronom":"Marseille",\n',
#  '      "dep_code":"13",\n',
#  '      "dep_nom":"Bouches-du-Rhône",\n',
#  '      "code_postal":"13000",\n',
#  '      "population":873076,\n',
#  '      "superficie_km2":241\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Caen",\n',
#  '      "nom_sans_pronom":"Caen",\n',
#  '      "dep_code":"14",\n',
#  '      "dep_nom":"Calvados",\n',
#  '      "code_postal":"14000",\n',
#  '      "population":108200,\n',
#  '      "superficie_km2":26\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Dijon",\n',
#  '      "nom_sans_pronom":"Dijon",\n',
#  '      "dep_code":"21",\n',
#  '      "dep_nom":"Côte-d\'Or",\n',
#  '      "code_postal":"21000",\n',
#  '      "population":159346,\n',
#  '      "superficie_km2":42\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Besançon",\n',
#  '      "nom_sans_pronom":"Besançon",\n',
#  '      "dep_code":"25",\n',
#  '      "dep_nom":"Doubs",\n',
#  '      "code_postal":"25000",\n',
#  '      "population":119198,\n',
#  '      "superficie_km2":65\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Brest",\n',
#  '      "nom_sans_pronom":"Brest",\n',
#  '      "dep_code":"29",\n',
#  '      "dep_nom":"Finistère",\n',
#  '      "code_postal":"29200",\n',
#  '      "population":139619,\n',
#  '      "superficie_km2":49\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nîmes",\n',
#  '      "nom_sans_pronom":"Nîmes",\n',
#  '      "dep_code":"30",\n',
#  '      "dep_nom":"Gard",\n',
#  '      "code_postal":"30900",\n',
#  '      "population":148104,\n',
#  '      "superficie_km2":161\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Toulouse",\n',
#  '      "nom_sans_pronom":"Toulouse",\n',
#  '      "dep_code":"31",\n',
#  '      "dep_nom":"Haute-Garonne",\n',
#  '      "code_postal":"31100",\n',
#  '      "population":504078,\n',
#  '      "superficie_km2":118\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Bordeaux",\n',
#  '      "nom_sans_pronom":"Bordeaux",\n',
#  '      "dep_code":"33",\n',
#  '      "dep_nom":"Gironde",\n',
#  '      "code_postal":"33300",\n',
#  '      "population":261804,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Montpellier",\n',
#  '      "nom_sans_pronom":"Montpellier",\n',
#  '      "dep_code":"34",\n',
#  '      "dep_nom":"Hérault",\n',
#  '      "code_postal":"34080",\n',
#  '      "population":302454,\n',
#  '      "superficie_km2":57\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Rennes",\n',
#  '      "nom_sans_pronom":"Rennes",\n',
#  '      "dep_code":"35",\n',
#  '      "dep_nom":"Ille-et-Vilaine",\n',
#  '      "code_postal":"35700",\n',
#  '      "population":225081,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Tours",\n',
#  '      "nom_sans_pronom":"Tours",\n',
#  '      "dep_code":"37",\n',
#  '      "dep_nom":"Indre-et-Loire",\n',
#  '      "code_postal":"37100",\n',
#  '      "population":137658,\n',
#  '      "superficie_km2":33\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Grenoble",\n',
#  '      "nom_sans_pronom":"Grenoble",\n',
#  '      "dep_code":"38",\n',
#  '      "dep_nom":"Isère",\n',
#  '      "code_postal":"38000",\n',
#  '      "population":157477,\n',
#  '      "superficie_km2":19\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Étienne",\n',
#  '      "nom_sans_pronom":"Saint-Étienne",\n',
#  '      "dep_code":"42",\n',
#  '      "dep_nom":"Loire",\n',
#  '      "code_postal":"42100",\n',
#  '      "population":172718,\n',
#  '      "superficie_km2":80\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nantes",\n',
#  '      "nom_sans_pronom":"Nantes",\n',
#  '      "dep_code":"44",\n',
#  '      "dep_nom":"Loire-Atlantique",\n',
#  '      "code_postal":"44200",\n',
#  '      "population":323204,\n',
#  '      "superficie_km2":66\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Orléans",\n',
#  '      "nom_sans_pronom":"Orléans",\n',
#  '      "dep_code":"45",\n',
#  '      "dep_nom":"Loiret",\n',
#  '      "code_postal":"45000",\n',
#  '      "population":116617,\n',
#  '      "superficie_km2":28\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Angers",\n',
#  '      "nom_sans_pronom":"Angers",\n',
#  '      "dep_code":"49",\n',
#  '      "dep_nom":"Maine-et-Loire",\n',
#  '      "code_postal":"49000",\n',
#  '      "population":157175,\n',
#  '      "superficie_km2":44\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Reims",\n',
#  '      "nom_sans_pronom":"Reims",\n',
#  '      "dep_code":"51",\n',
#  '      "dep_nom":"Marne",\n',
#  '      "code_postal":"51100",\n',
#  '      "population":179380,\n',
#  '      "superficie_km2":47\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nancy",\n',
#  '      "nom_sans_pronom":"Nancy",\n',
#  '      "dep_code":"54",\n',
#  '      "dep_nom":"Meurthe-et-Moselle",\n',
#  '      "code_postal":"54100",\n',
#  '      "population":104260,\n',
#  '      "superficie_km2":15\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Metz",\n',
#  '      "nom_sans_pronom":"Metz",\n',
#  '      "dep_code":"57",\n',
#  '      "dep_nom":"Moselle",\n',
#  '      "code_postal":"57070",\n',
#  '      "population":120874,\n',
#  '      "superficie_km2":42\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Lille",\n',
#  '      "nom_sans_pronom":"Lille",\n',
#  '      "dep_code":"59",\n',
#  '      "dep_nom":"Nord",\n',
#  '      "code_postal":"59260",\n',
#  '      "population":236710,\n',
#  '      "superficie_km2":35\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Clermont-Ferrand",\n',
#  '      "nom_sans_pronom":"Clermont-Ferrand",\n',
#  '      "dep_code":"63",\n',
#  '      "dep_nom":"Puy-de-Dôme",\n',
#  '      "code_postal":"63100",\n',
#  '      "population":147327,\n',
#  '      "superficie_km2":43\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Perpignan",\n',
#  '      "nom_sans_pronom":"Perpignan",\n',
#  '      "dep_code":"66",\n',
#  '      "dep_nom":"Pyrénées-Orientales",\n',
#  '      "code_postal":"66000",\n',
#  '      "population":119656,\n',
#  '      "superficie_km2":68\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Strasbourg",\n',
#  '      "nom_sans_pronom":"Strasbourg",\n',
#  '      "dep_code":"67",\n',
#  '      "dep_nom":"Bas-Rhin",\n',
#  '      "code_postal":"67000",\n',
#  '      "population":291313,\n',
#  '      "superficie_km2":78\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Mulhouse",\n',
#  '      "nom_sans_pronom":"Mulhouse",\n',
#  '      "dep_code":"68",\n',
#  '      "dep_nom":"Haut-Rhin",\n',
#  '      "code_postal":"68200",\n',
#  '      "population":106341,\n',
#  '      "superficie_km2":22\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Lyon",\n',
#  '      "nom_sans_pronom":"Lyon",\n',
#  '      "dep_code":"69",\n',
#  '      "dep_nom":"Rhône",\n',
#  '      "code_postal":"69000",\n',
#  '      "population":522250,\n',
#  '      "superficie_km2":48\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Villeurbanne",\n',
#  '      "nom_sans_pronom":"Villeurbanne",\n',
#  '      "dep_code":"69",\n',
#  '      "dep_nom":"Rhône",\n',
#  '      "code_postal":"69100",\n',
#  '      "population":156928,\n',
#  '      "superficie_km2":15\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Le Mans",\n',
#  '      "nom_sans_pronom":"Mans",\n',
#  '      "dep_code":"72",\n',
#  '      "dep_nom":"Sarthe",\n',
#  '      "code_postal":"72100",\n',
#  '      "population":145004,\n',
#  '      "superficie_km2":53\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Annecy",\n',
#  '      "nom_sans_pronom":"Annecy",\n',
#  '      "dep_code":"74",\n',
#  '      "dep_nom":"Haute-Savoie",\n',
#  '      "code_postal":"74000",\n',
#  '      "population":131715,\n',
#  '      "superficie_km2":16\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Paris",\n',
#  '      "nom_sans_pronom":"Paris",\n',
#  '      "dep_code":"75",\n',
#  '      "dep_nom":"Paris",\n',
#  '      "code_postal":"75000",\n',
#  '      "population":2133111,\n',
#  '      "superficie_km2":105\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Le Havre",\n',
#  '      "nom_sans_pronom":"Havre",\n',
#  '      "dep_code":"76",\n',
#  '      "dep_nom":"Seine-Maritime",\n',
#  '      "code_postal":"76620",\n',
#  '      "population":166058,\n',
#  '      "superficie_km2":55\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Rouen",\n',
#  '      "nom_sans_pronom":"Rouen",\n',
#  '      "dep_code":"76",\n',
#  '      "dep_nom":"Seine-Maritime",\n',
#  '      "code_postal":"76100",\n',
#  '      "population":114083,\n',
#  '      "superficie_km2":21\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Amiens",\n',
#  '      "nom_sans_pronom":"Amiens",\n',
#  '      "dep_code":"80",\n',
#  '      "dep_nom":"Somme",\n',
#  '      "code_postal":"80090",\n',
#  '      "population":133625,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Toulon",\n',
#  '      "nom_sans_pronom":"Toulon",\n',
#  '      "dep_code":"83",\n',
#  '      "dep_nom":"Var",\n',
#  '      "code_postal":"83000",\n',
#  '      "population":180452,\n',
#  '      "superficie_km2":44\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Limoges",\n',
#  '      "nom_sans_pronom":"Limoges",\n',
#  '      "dep_code":"87",\n',
#  '      "dep_nom":"Haute-Vienne",\n',
#  '      "code_postal":"87100",\n',
#  '      "population":129760,\n',
#  '      "superficie_km2":80\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Boulogne-Billancourt",\n',
#  '      "nom_sans_pronom":"Boulogne-Billancourt",\n',
#  '      "dep_code":"92",\n',
#  '      "dep_nom":"Hauts-de-Seine",\n',
#  '      "code_postal":"92100",\n',
#  '      "population":119808,\n',
#  '      "superficie_km2":6\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Montreuil",\n',
#  '      "nom_sans_pronom":"Montreuil",\n',
#  '      "dep_code":"93",\n',
#  '      "dep_nom":"Seine-Saint-Denis",\n',
#  '      "code_postal":"93100",\n',
#  '      "population":111455,\n',
#  '      "superficie_km2":9\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Denis",\n',
#  '      "nom_sans_pronom":"Saint-Denis",\n',
#  '      "dep_code":"93",\n',
#  '      "dep_nom":"Seine-Saint-Denis",\n',
#  '      "code_postal":"93210",\n',
#  '      "population":113942,\n',
#  '      "superficie_km2":12\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Argenteuil",\n',
#  '      "nom_sans_pronom":"Argenteuil",\n',
#  '      "dep_code":"95",\n',
#  '      "dep_nom":"Val-d\'Oise",\n',
#  '      "code_postal":"95100",\n',
#  '      "population":107221,\n',
#  '      "superficie_km2":17\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Denis",\n',
#  '      "nom_sans_pronom":"Saint-Denis",\n',
#  '      "dep_code":"974",\n',
#  '      "dep_nom":"La Réunion",\n',
#  '      "code_postal":"97400",\n',
#  '      "population":154765,\n',
#  '      "superficie_km2":142\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Paul",\n',
#  '      "nom_sans_pronom":"Saint-Paul",\n',
#  '      "dep_code":"974",\n',
#  '      "dep_nom":"La Réunion",\n',
#  '      "code_postal":"97411",\n',
#  '      "population":105240,\n',
#  '      "superficie_km2":240\n',
#  '   }\n',
#  ']']

# %%
f.close()

# %%
with open('data/villes100k.json', encoding='UTF-8') as f:
    data = list(f)
# f.close() même si exception
data
# Out:
# ['[\n',
#  '   {\n',
#  '      "nom_standard":"Nice",\n',
#  '      "nom_sans_pronom":"Nice",\n',
#  '      "dep_code":"06",\n',
#  '      "dep_nom":"Alpes-Maritimes",\n',
#  '      "code_postal":"06000",\n',
#  '      "population":348085,\n',
#  '      "superficie_km2":74\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Aix-en-Provence",\n',
#  '      "nom_sans_pronom":"Aix-en-Provence",\n',
#  '      "dep_code":"13",\n',
#  '      "dep_nom":"Bouches-du-Rhône",\n',
#  '      "code_postal":"13100",\n',
#  '      "population":147478,\n',
#  '      "superficie_km2":188\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Marseille",\n',
#  '      "nom_sans_pronom":"Marseille",\n',
#  '      "dep_code":"13",\n',
#  '      "dep_nom":"Bouches-du-Rhône",\n',
#  '      "code_postal":"13000",\n',
#  '      "population":873076,\n',
#  '      "superficie_km2":241\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Caen",\n',
#  '      "nom_sans_pronom":"Caen",\n',
#  '      "dep_code":"14",\n',
#  '      "dep_nom":"Calvados",\n',
#  '      "code_postal":"14000",\n',
#  '      "population":108200,\n',
#  '      "superficie_km2":26\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Dijon",\n',
#  '      "nom_sans_pronom":"Dijon",\n',
#  '      "dep_code":"21",\n',
#  '      "dep_nom":"Côte-d\'Or",\n',
#  '      "code_postal":"21000",\n',
#  '      "population":159346,\n',
#  '      "superficie_km2":42\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Besançon",\n',
#  '      "nom_sans_pronom":"Besançon",\n',
#  '      "dep_code":"25",\n',
#  '      "dep_nom":"Doubs",\n',
#  '      "code_postal":"25000",\n',
#  '      "population":119198,\n',
#  '      "superficie_km2":65\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Brest",\n',
#  '      "nom_sans_pronom":"Brest",\n',
#  '      "dep_code":"29",\n',
#  '      "dep_nom":"Finistère",\n',
#  '      "code_postal":"29200",\n',
#  '      "population":139619,\n',
#  '      "superficie_km2":49\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nîmes",\n',
#  '      "nom_sans_pronom":"Nîmes",\n',
#  '      "dep_code":"30",\n',
#  '      "dep_nom":"Gard",\n',
#  '      "code_postal":"30900",\n',
#  '      "population":148104,\n',
#  '      "superficie_km2":161\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Toulouse",\n',
#  '      "nom_sans_pronom":"Toulouse",\n',
#  '      "dep_code":"31",\n',
#  '      "dep_nom":"Haute-Garonne",\n',
#  '      "code_postal":"31100",\n',
#  '      "population":504078,\n',
#  '      "superficie_km2":118\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Bordeaux",\n',
#  '      "nom_sans_pronom":"Bordeaux",\n',
#  '      "dep_code":"33",\n',
#  '      "dep_nom":"Gironde",\n',
#  '      "code_postal":"33300",\n',
#  '      "population":261804,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Montpellier",\n',
#  '      "nom_sans_pronom":"Montpellier",\n',
#  '      "dep_code":"34",\n',
#  '      "dep_nom":"Hérault",\n',
#  '      "code_postal":"34080",\n',
#  '      "population":302454,\n',
#  '      "superficie_km2":57\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Rennes",\n',
#  '      "nom_sans_pronom":"Rennes",\n',
#  '      "dep_code":"35",\n',
#  '      "dep_nom":"Ille-et-Vilaine",\n',
#  '      "code_postal":"35700",\n',
#  '      "population":225081,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Tours",\n',
#  '      "nom_sans_pronom":"Tours",\n',
#  '      "dep_code":"37",\n',
#  '      "dep_nom":"Indre-et-Loire",\n',
#  '      "code_postal":"37100",\n',
#  '      "population":137658,\n',
#  '      "superficie_km2":33\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Grenoble",\n',
#  '      "nom_sans_pronom":"Grenoble",\n',
#  '      "dep_code":"38",\n',
#  '      "dep_nom":"Isère",\n',
#  '      "code_postal":"38000",\n',
#  '      "population":157477,\n',
#  '      "superficie_km2":19\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Étienne",\n',
#  '      "nom_sans_pronom":"Saint-Étienne",\n',
#  '      "dep_code":"42",\n',
#  '      "dep_nom":"Loire",\n',
#  '      "code_postal":"42100",\n',
#  '      "population":172718,\n',
#  '      "superficie_km2":80\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nantes",\n',
#  '      "nom_sans_pronom":"Nantes",\n',
#  '      "dep_code":"44",\n',
#  '      "dep_nom":"Loire-Atlantique",\n',
#  '      "code_postal":"44200",\n',
#  '      "population":323204,\n',
#  '      "superficie_km2":66\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Orléans",\n',
#  '      "nom_sans_pronom":"Orléans",\n',
#  '      "dep_code":"45",\n',
#  '      "dep_nom":"Loiret",\n',
#  '      "code_postal":"45000",\n',
#  '      "population":116617,\n',
#  '      "superficie_km2":28\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Angers",\n',
#  '      "nom_sans_pronom":"Angers",\n',
#  '      "dep_code":"49",\n',
#  '      "dep_nom":"Maine-et-Loire",\n',
#  '      "code_postal":"49000",\n',
#  '      "population":157175,\n',
#  '      "superficie_km2":44\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Reims",\n',
#  '      "nom_sans_pronom":"Reims",\n',
#  '      "dep_code":"51",\n',
#  '      "dep_nom":"Marne",\n',
#  '      "code_postal":"51100",\n',
#  '      "population":179380,\n',
#  '      "superficie_km2":47\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Nancy",\n',
#  '      "nom_sans_pronom":"Nancy",\n',
#  '      "dep_code":"54",\n',
#  '      "dep_nom":"Meurthe-et-Moselle",\n',
#  '      "code_postal":"54100",\n',
#  '      "population":104260,\n',
#  '      "superficie_km2":15\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Metz",\n',
#  '      "nom_sans_pronom":"Metz",\n',
#  '      "dep_code":"57",\n',
#  '      "dep_nom":"Moselle",\n',
#  '      "code_postal":"57070",\n',
#  '      "population":120874,\n',
#  '      "superficie_km2":42\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Lille",\n',
#  '      "nom_sans_pronom":"Lille",\n',
#  '      "dep_code":"59",\n',
#  '      "dep_nom":"Nord",\n',
#  '      "code_postal":"59260",\n',
#  '      "population":236710,\n',
#  '      "superficie_km2":35\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Clermont-Ferrand",\n',
#  '      "nom_sans_pronom":"Clermont-Ferrand",\n',
#  '      "dep_code":"63",\n',
#  '      "dep_nom":"Puy-de-Dôme",\n',
#  '      "code_postal":"63100",\n',
#  '      "population":147327,\n',
#  '      "superficie_km2":43\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Perpignan",\n',
#  '      "nom_sans_pronom":"Perpignan",\n',
#  '      "dep_code":"66",\n',
#  '      "dep_nom":"Pyrénées-Orientales",\n',
#  '      "code_postal":"66000",\n',
#  '      "population":119656,\n',
#  '      "superficie_km2":68\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Strasbourg",\n',
#  '      "nom_sans_pronom":"Strasbourg",\n',
#  '      "dep_code":"67",\n',
#  '      "dep_nom":"Bas-Rhin",\n',
#  '      "code_postal":"67000",\n',
#  '      "population":291313,\n',
#  '      "superficie_km2":78\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Mulhouse",\n',
#  '      "nom_sans_pronom":"Mulhouse",\n',
#  '      "dep_code":"68",\n',
#  '      "dep_nom":"Haut-Rhin",\n',
#  '      "code_postal":"68200",\n',
#  '      "population":106341,\n',
#  '      "superficie_km2":22\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Lyon",\n',
#  '      "nom_sans_pronom":"Lyon",\n',
#  '      "dep_code":"69",\n',
#  '      "dep_nom":"Rhône",\n',
#  '      "code_postal":"69000",\n',
#  '      "population":522250,\n',
#  '      "superficie_km2":48\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Villeurbanne",\n',
#  '      "nom_sans_pronom":"Villeurbanne",\n',
#  '      "dep_code":"69",\n',
#  '      "dep_nom":"Rhône",\n',
#  '      "code_postal":"69100",\n',
#  '      "population":156928,\n',
#  '      "superficie_km2":15\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Le Mans",\n',
#  '      "nom_sans_pronom":"Mans",\n',
#  '      "dep_code":"72",\n',
#  '      "dep_nom":"Sarthe",\n',
#  '      "code_postal":"72100",\n',
#  '      "population":145004,\n',
#  '      "superficie_km2":53\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Annecy",\n',
#  '      "nom_sans_pronom":"Annecy",\n',
#  '      "dep_code":"74",\n',
#  '      "dep_nom":"Haute-Savoie",\n',
#  '      "code_postal":"74000",\n',
#  '      "population":131715,\n',
#  '      "superficie_km2":16\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Paris",\n',
#  '      "nom_sans_pronom":"Paris",\n',
#  '      "dep_code":"75",\n',
#  '      "dep_nom":"Paris",\n',
#  '      "code_postal":"75000",\n',
#  '      "population":2133111,\n',
#  '      "superficie_km2":105\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Le Havre",\n',
#  '      "nom_sans_pronom":"Havre",\n',
#  '      "dep_code":"76",\n',
#  '      "dep_nom":"Seine-Maritime",\n',
#  '      "code_postal":"76620",\n',
#  '      "population":166058,\n',
#  '      "superficie_km2":55\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Rouen",\n',
#  '      "nom_sans_pronom":"Rouen",\n',
#  '      "dep_code":"76",\n',
#  '      "dep_nom":"Seine-Maritime",\n',
#  '      "code_postal":"76100",\n',
#  '      "population":114083,\n',
#  '      "superficie_km2":21\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Amiens",\n',
#  '      "nom_sans_pronom":"Amiens",\n',
#  '      "dep_code":"80",\n',
#  '      "dep_nom":"Somme",\n',
#  '      "code_postal":"80090",\n',
#  '      "population":133625,\n',
#  '      "superficie_km2":50\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Toulon",\n',
#  '      "nom_sans_pronom":"Toulon",\n',
#  '      "dep_code":"83",\n',
#  '      "dep_nom":"Var",\n',
#  '      "code_postal":"83000",\n',
#  '      "population":180452,\n',
#  '      "superficie_km2":44\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Limoges",\n',
#  '      "nom_sans_pronom":"Limoges",\n',
#  '      "dep_code":"87",\n',
#  '      "dep_nom":"Haute-Vienne",\n',
#  '      "code_postal":"87100",\n',
#  '      "population":129760,\n',
#  '      "superficie_km2":80\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Boulogne-Billancourt",\n',
#  '      "nom_sans_pronom":"Boulogne-Billancourt",\n',
#  '      "dep_code":"92",\n',
#  '      "dep_nom":"Hauts-de-Seine",\n',
#  '      "code_postal":"92100",\n',
#  '      "population":119808,\n',
#  '      "superficie_km2":6\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Montreuil",\n',
#  '      "nom_sans_pronom":"Montreuil",\n',
#  '      "dep_code":"93",\n',
#  '      "dep_nom":"Seine-Saint-Denis",\n',
#  '      "code_postal":"93100",\n',
#  '      "population":111455,\n',
#  '      "superficie_km2":9\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Denis",\n',
#  '      "nom_sans_pronom":"Saint-Denis",\n',
#  '      "dep_code":"93",\n',
#  '      "dep_nom":"Seine-Saint-Denis",\n',
#  '      "code_postal":"93210",\n',
#  '      "population":113942,\n',
#  '      "superficie_km2":12\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Argenteuil",\n',
#  '      "nom_sans_pronom":"Argenteuil",\n',
#  '      "dep_code":"95",\n',
#  '      "dep_nom":"Val-d\'Oise",\n',
#  '      "code_postal":"95100",\n',
#  '      "population":107221,\n',
#  '      "superficie_km2":17\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Denis",\n',
#  '      "nom_sans_pronom":"Saint-Denis",\n',
#  '      "dep_code":"974",\n',
#  '      "dep_nom":"La Réunion",\n',
#  '      "code_postal":"97400",\n',
#  '      "population":154765,\n',
#  '      "superficie_km2":142\n',
#  '   },\n',
#  '   {\n',
#  '      "nom_standard":"Saint-Paul",\n',
#  '      "nom_sans_pronom":"Saint-Paul",\n',
#  '      "dep_code":"974",\n',
#  '      "dep_nom":"La Réunion",\n',
#  '      "code_postal":"97411",\n',
#  '      "population":105240,\n',
#  '      "superficie_km2":240\n',
#  '   }\n',
#  ']']

# %%
with open('data/villes100k.json', encoding='UTF-8') as f:
    data = json.load(f)
# f.close() même si exception
data
# Out:
# [{'nom_standard': 'Nice',
#   'nom_sans_pronom': 'Nice',
#   'dep_code': '06',
#   'dep_nom': 'Alpes-Maritimes',
#   'code_postal': '06000',
#   'population': 348085,
#   'superficie_km2': 74},
#  {'nom_standard': 'Aix-en-Provence',
#   'nom_sans_pronom': 'Aix-en-Provence',
#   'dep_code': '13',
#   'dep_nom': 'Bouches-du-Rhône',
#   'code_postal': '13100',
#   'population': 147478,
#   'superficie_km2': 188},
#  {'nom_standard': 'Marseille',
#   'nom_sans_pronom': 'Marseille',
#   'dep_code': '13',
#   'dep_nom': 'Bouches-du-Rhône',
#   'code_postal': '13000',
#   'population': 873076,
#   'superficie_km2': 241},
#  {'nom_standard': 'Caen',
#   'nom_sans_pronom': 'Caen',
#   'dep_code': '14',
#   'dep_nom': 'Calvados',
#   'code_postal': '14000',
#   'population': 108200,
#   'superficie_km2': 26},
#  {'nom_standard': 'Dijon',
#   'nom_sans_pronom': 'Dijon',
#   'dep_code': '21',
#   'dep_nom': "Côte-d'Or",
#   'code_postal': '21000',
#   'population': 159346,
#   'superficie_km2': 42},
#  {'nom_standard': 'Besançon',
#   'nom_sans_pronom': 'Besançon',
#   'dep_code': '25',
#   'dep_nom': 'Doubs',
#   'code_postal': '25000',
#   'population': 119198,
#   'superficie_km2': 65},
#  {'nom_standard': 'Brest',
#   'nom_sans_pronom': 'Brest',
#   'dep_code': '29',
#   'dep_nom': 'Finistère',
#   'code_postal': '29200',
#   'population': 139619,
#   'superficie_km2': 49},
#  {'nom_standard': 'Nîmes',
#   'nom_sans_pronom': 'Nîmes',
#   'dep_code': '30',
#   'dep_nom': 'Gard',
#   'code_postal': '30900',
#   'population': 148104,
#   'superficie_km2': 161},
#  {'nom_standard': 'Toulouse',
#   'nom_sans_pronom': 'Toulouse',
#   'dep_code': '31',
#   'dep_nom': 'Haute-Garonne',
#   'code_postal': '31100',
#   'population': 504078,
#   'superficie_km2': 118},
#  {'nom_standard': 'Bordeaux',
#   'nom_sans_pronom': 'Bordeaux',
#   'dep_code': '33',
#   'dep_nom': 'Gironde',
#   'code_postal': '33300',
#   'population': 261804,
#   'superficie_km2': 50},
#  {'nom_standard': 'Montpellier',
#   'nom_sans_pronom': 'Montpellier',
#   'dep_code': '34',
#   'dep_nom': 'Hérault',
#   'code_postal': '34080',
#   'population': 302454,
#   'superficie_km2': 57},
#  {'nom_standard': 'Rennes',
#   'nom_sans_pronom': 'Rennes',
#   'dep_code': '35',
#   'dep_nom': 'Ille-et-Vilaine',
#   'code_postal': '35700',
#   'population': 225081,
#   'superficie_km2': 50},
#  {'nom_standard': 'Tours',
#   'nom_sans_pronom': 'Tours',
#   'dep_code': '37',
#   'dep_nom': 'Indre-et-Loire',
#   'code_postal': '37100',
#   'population': 137658,
#   'superficie_km2': 33},
#  {'nom_standard': 'Grenoble',
#   'nom_sans_pronom': 'Grenoble',
#   'dep_code': '38',
#   'dep_nom': 'Isère',
#   'code_postal': '38000',
#   'population': 157477,
#   'superficie_km2': 19},
#  {'nom_standard': 'Saint-Étienne',
#   'nom_sans_pronom': 'Saint-Étienne',
#   'dep_code': '42',
#   'dep_nom': 'Loire',
#   'code_postal': '42100',
#   'population': 172718,
#   'superficie_km2': 80},
#  {'nom_standard': 'Nantes',
#   'nom_sans_pronom': 'Nantes',
#   'dep_code': '44',
#   'dep_nom': 'Loire-Atlantique',
#   'code_postal': '44200',
#   'population': 323204,
#   'superficie_km2': 66},
#  {'nom_standard': 'Orléans',
#   'nom_sans_pronom': 'Orléans',
#   'dep_code': '45',
#   'dep_nom': 'Loiret',
#   'code_postal': '45000',
#   'population': 116617,
#   'superficie_km2': 28},
#  {'nom_standard': 'Angers',
#   'nom_sans_pronom': 'Angers',
#   'dep_code': '49',
#   'dep_nom': 'Maine-et-Loire',
#   'code_postal': '49000',
#   'population': 157175,
#   'superficie_km2': 44},
#  {'nom_standard': 'Reims',
#   'nom_sans_pronom': 'Reims',
#   'dep_code': '51',
#   'dep_nom': 'Marne',
#   'code_postal': '51100',
#   'population': 179380,
#   'superficie_km2': 47},
#  {'nom_standard': 'Nancy',
#   'nom_sans_pronom': 'Nancy',
#   'dep_code': '54',
#   'dep_nom': 'Meurthe-et-Moselle',
#   'code_postal': '54100',
#   'population': 104260,
#   'superficie_km2': 15},
#  {'nom_standard': 'Metz',
#   'nom_sans_pronom': 'Metz',
#   'dep_code': '57',
#   'dep_nom': 'Moselle',
#   'code_postal': '57070',
#   'population': 120874,
#   'superficie_km2': 42},
#  {'nom_standard': 'Lille',
#   'nom_sans_pronom': 'Lille',
#   'dep_code': '59',
#   'dep_nom': 'Nord',
#   'code_postal': '59260',
#   'population': 236710,
#   'superficie_km2': 35},
#  {'nom_standard': 'Clermont-Ferrand',
#   'nom_sans_pronom': 'Clermont-Ferrand',
#   'dep_code': '63',
#   'dep_nom': 'Puy-de-Dôme',
#   'code_postal': '63100',
#   'population': 147327,
#   'superficie_km2': 43},
#  {'nom_standard': 'Perpignan',
#   'nom_sans_pronom': 'Perpignan',
#   'dep_code': '66',
#   'dep_nom': 'Pyrénées-Orientales',
#   'code_postal': '66000',
#   'population': 119656,
#   'superficie_km2': 68},
#  {'nom_standard': 'Strasbourg',
#   'nom_sans_pronom': 'Strasbourg',
#   'dep_code': '67',
#   'dep_nom': 'Bas-Rhin',
#   'code_postal': '67000',
#   'population': 291313,
#   'superficie_km2': 78},
#  {'nom_standard': 'Mulhouse',
#   'nom_sans_pronom': 'Mulhouse',
#   'dep_code': '68',
#   'dep_nom': 'Haut-Rhin',
#   'code_postal': '68200',
#   'population': 106341,
#   'superficie_km2': 22},
#  {'nom_standard': 'Lyon',
#   'nom_sans_pronom': 'Lyon',
#   'dep_code': '69',
#   'dep_nom': 'Rhône',
#   'code_postal': '69000',
#   'population': 522250,
#   'superficie_km2': 48},
#  {'nom_standard': 'Villeurbanne',
#   'nom_sans_pronom': 'Villeurbanne',
#   'dep_code': '69',
#   'dep_nom': 'Rhône',
#   'code_postal': '69100',
#   'population': 156928,
#   'superficie_km2': 15},
#  {'nom_standard': 'Le Mans',
#   'nom_sans_pronom': 'Mans',
#   'dep_code': '72',
#   'dep_nom': 'Sarthe',
#   'code_postal': '72100',
#   'population': 145004,
#   'superficie_km2': 53},
#  {'nom_standard': 'Annecy',
#   'nom_sans_pronom': 'Annecy',
#   'dep_code': '74',
#   'dep_nom': 'Haute-Savoie',
#   'code_postal': '74000',
#   'population': 131715,
#   'superficie_km2': 16},
#  {'nom_standard': 'Paris',
#   'nom_sans_pronom': 'Paris',
#   'dep_code': '75',
#   'dep_nom': 'Paris',
#   'code_postal': '75000',
#   'population': 2133111,
#   'superficie_km2': 105},
#  {'nom_standard': 'Le Havre',
#   'nom_sans_pronom': 'Havre',
#   'dep_code': '76',
#   'dep_nom': 'Seine-Maritime',
#   'code_postal': '76620',
#   'population': 166058,
#   'superficie_km2': 55},
#  {'nom_standard': 'Rouen',
#   'nom_sans_pronom': 'Rouen',
#   'dep_code': '76',
#   'dep_nom': 'Seine-Maritime',
#   'code_postal': '76100',
#   'population': 114083,
#   'superficie_km2': 21},
#  {'nom_standard': 'Amiens',
#   'nom_sans_pronom': 'Amiens',
#   'dep_code': '80',
#   'dep_nom': 'Somme',
#   'code_postal': '80090',
#   'population': 133625,
#   'superficie_km2': 50},
#  {'nom_standard': 'Toulon',
#   'nom_sans_pronom': 'Toulon',
#   'dep_code': '83',
#   'dep_nom': 'Var',
#   'code_postal': '83000',
#   'population': 180452,
#   'superficie_km2': 44},
#  {'nom_standard': 'Limoges',
#   'nom_sans_pronom': 'Limoges',
#   'dep_code': '87',
#   'dep_nom': 'Haute-Vienne',
#   'code_postal': '87100',
#   'population': 129760,
#   'superficie_km2': 80},
#  {'nom_standard': 'Boulogne-Billancourt',
#   'nom_sans_pronom': 'Boulogne-Billancourt',
#   'dep_code': '92',
#   'dep_nom': 'Hauts-de-Seine',
#   'code_postal': '92100',
#   'population': 119808,
#   'superficie_km2': 6},
#  {'nom_standard': 'Montreuil',
#   'nom_sans_pronom': 'Montreuil',
#   'dep_code': '93',
#   'dep_nom': 'Seine-Saint-Denis',
#   'code_postal': '93100',
#   'population': 111455,
#   'superficie_km2': 9},
#  {'nom_standard': 'Saint-Denis',
#   'nom_sans_pronom': 'Saint-Denis',
#   'dep_code': '93',
#   'dep_nom': 'Seine-Saint-Denis',
#   'code_postal': '93210',
#   'population': 113942,
#   'superficie_km2': 12},
#  {'nom_standard': 'Argenteuil',
#   'nom_sans_pronom': 'Argenteuil',
#   'dep_code': '95',
#   'dep_nom': "Val-d'Oise",
#   'code_postal': '95100',
#   'population': 107221,
#   'superficie_km2': 17},
#  {'nom_standard': 'Saint-Denis',
#   'nom_sans_pronom': 'Saint-Denis',
#   'dep_code': '974',
#   'dep_nom': 'La Réunion',
#   'code_postal': '97400',
#   'population': 154765,
#   'superficie_km2': 142},
#  {'nom_standard': 'Saint-Paul',
#   'nom_sans_pronom': 'Saint-Paul',
#   'dep_code': '974',
#   'dep_nom': 'La Réunion',
#   'code_postal': '97411',
#   'population': 105240,
#   'superficie_km2': 240}]

# %%
type(data)
# Out:
# list

# %%
city = data[0]
print(city)
print(len(city))
type(city)
# Out:
# {'nom_standard': 'Nice', 'nom_sans_pronom': 'Nice', 'dep_code': '06', 'dep_nom': 'Alpes-Maritimes', 'code_postal': '06000', 'population': 348085, 'superficie_km2': 74}
# 7
# dict

# %%
city['nom_standard']
# Out:
# 'Nice'

# %%
# 3 parcours: .keys(), .values(), .items()
for info_name, info_value in city.items():
    print(info_name, info_value, sep=' = ')
# Out:
# nom_standard = Nice
# nom_sans_pronom = Nice
# dep_code = 06
# dep_nom = Alpes-Maritimes
# code_postal = 06000
# population = 348085
# superficie_km2 = 74

# %%
# 1. villes de population >= 500_000
# 2. population totale du département 13

# %%
for city in data[:3]:
    print(city)
    print(city['population'])
# Out:
# {'nom_standard': 'Nice', 'nom_sans_pronom': 'Nice', 'dep_code': '06', 'dep_nom': 'Alpes-Maritimes', 'code_postal': '06000', 'population': 348085, 'superficie_km2': 74}
# 348085
# {'nom_standard': 'Aix-en-Provence', 'nom_sans_pronom': 'Aix-en-Provence', 'dep_code': '13', 'dep_nom': 'Bouches-du-Rhône', 'code_postal': '13100', 'population': 147478, 'superficie_km2': 188}
# 147478
# {'nom_standard': 'Marseille', 'nom_sans_pronom': 'Marseille', 'dep_code': '13', 'dep_nom': 'Bouches-du-Rhône', 'code_postal': '13000', 'population': 873076, 'superficie_km2': 241}
# 873076

# %%
cities_500k = []
for city in data:
    if city['population'] >= 500_000:
        # print(city)
        cities_500k.append(city)

# pretty print
for city in cities_500k:
    print(city)
# Out:
# {'nom_standard': 'Marseille', 'nom_sans_pronom': 'Marseille', 'dep_code': '13', 'dep_nom': 'Bouches-du-Rhône', 'code_postal': '13000', 'population': 873076, 'superficie_km2': 241}
# {'nom_standard': 'Toulouse', 'nom_sans_pronom': 'Toulouse', 'dep_code': '31', 'dep_nom': 'Haute-Garonne', 'code_postal': '31100', 'population': 504078, 'superficie_km2': 118}
# {'nom_standard': 'Lyon', 'nom_sans_pronom': 'Lyon', 'dep_code': '69', 'dep_nom': 'Rhône', 'code_postal': '69000', 'population': 522250, 'superficie_km2': 48}
# {'nom_standard': 'Paris', 'nom_sans_pronom': 'Paris', 'dep_code': '75', 'dep_nom': 'Paris', 'code_postal': '75000', 'population': 2133111, 'superficie_km2': 105}

# %%
cities_500k = [city for city in data if city['population'] >= 500_000]

# pretty print
for city in cities_500k:
    print(city)
# Out:
# {'nom_standard': 'Marseille', 'nom_sans_pronom': 'Marseille', 'dep_code': '13', 'dep_nom': 'Bouches-du-Rhône', 'code_postal': '13000', 'population': 873076, 'superficie_km2': 241}
# {'nom_standard': 'Toulouse', 'nom_sans_pronom': 'Toulouse', 'dep_code': '31', 'dep_nom': 'Haute-Garonne', 'code_postal': '31100', 'population': 504078, 'superficie_km2': 118}
# {'nom_standard': 'Lyon', 'nom_sans_pronom': 'Lyon', 'dep_code': '69', 'dep_nom': 'Rhône', 'code_postal': '69000', 'population': 522250, 'superficie_km2': 48}
# {'nom_standard': 'Paris', 'nom_sans_pronom': 'Paris', 'dep_code': '75', 'dep_nom': 'Paris', 'code_postal': '75000', 'population': 2133111, 'superficie_km2': 105}

# %%
population13 = sum(city['population'] for city in data if city['dep_code'] == '13')
population13
# Out:
# 1020554

# %%
df_cities = pd.DataFrame(data)
df_cities
# Out:
#             nom_standard       nom_sans_pronom dep_code              dep_nom  \
# 0                   Nice                  Nice       06      Alpes-Maritimes
# 1        Aix-en-Provence       Aix-en-Provence       13     Bouches-du-Rhône
# 2              Marseille             Marseille       13     Bouches-du-Rhône
# 3                   Caen                  Caen       14             Calvados
# 4                  Dijon                 Dijon       21            Côte-d'Or
# 5               Besançon              Besançon       25                Doubs
# 6                  Brest                 Brest       29            Finistère
# 7                  Nîmes                 Nîmes       30                 Gard
# 8               Toulouse              Toulouse       31        Haute-Garonne
# 9               Bordeaux              Bordeaux       33              Gironde
# 10           Montpellier           Montpellier       34              Hérault
# 11                Rennes                Rennes       35      Ille-et-Vilaine
# 12                 Tours                 Tours       37       Indre-et-Loire
# 13              Grenoble              Grenoble       38                Isère
# 14         Saint-Étienne         Saint-Étienne       42                Loire
# 15                Nantes                Nantes       44     Loire-Atlantique
# 16               Orléans               Orléans       45               Loiret
# 17                Angers                Angers       49       Maine-et-Loire
# 18                 Reims                 Reims       51                Marne
# 19                 Nancy                 Nancy       54   Meurthe-et-Moselle
# 20                  Metz                  Metz       57              Moselle
# 21                 Lille                 Lille       59                 Nord
# 22      Clermont-Ferrand      Clermont-Ferrand       63          Puy-de-Dôme
# 23             Perpignan             Perpignan       66  Pyrénées-Orientales
# 24            Strasbourg            Strasbourg       67             Bas-Rhin
# 25              Mulhouse              Mulhouse       68            Haut-Rhin
# 26                  Lyon                  Lyon       69                Rhône
# 27          Villeurbanne          Villeurbanne       69                Rhône
# 28               Le Mans                  Mans       72               Sarthe
# 29                Annecy                Annecy       74         Haute-Savoie
# 30                 Paris                 Paris       75                Paris
# 31              Le Havre                 Havre       76       Seine-Maritime
# 32                 Rouen                 Rouen       76       Seine-Maritime
# 33                Amiens                Amiens       80                Somme
# 34                Toulon                Toulon       83                  Var
# 35               Limoges               Limoges       87         Haute-Vienne
# 36  Boulogne-Billancourt  Boulogne-Billancourt       92       Hauts-de-Seine
# 37             Montreuil             Montreuil       93    Seine-Saint-Denis
# 38           Saint-Denis           Saint-Denis       93    Seine-Saint-Denis
# 39            Argenteuil            Argenteuil       95           Val-d'Oise
# 40           Saint-Denis           Saint-Denis      974           La Réunion
# 41            Saint-Paul            Saint-Paul      974           La Réunion
#
#    code_postal  population  superficie_km2
# 0        06000      348085              74
# 1        13100      147478             188
# 2        13000      873076             241
# 3        14000      108200              26
# 4        21000      159346              42
# 5        25000      119198              65
# 6        29200      139619              49
# 7        30900      148104             161
# 8        31100      504078             118
# 9        33300      261804              50
# 10       34080      302454              57
# 11       35700      225081              50
# 12       37100      137658              33
# 13       38000      157477              19
# 14       42100      172718              80
# 15       44200      323204              66
# 16       45000      116617              28
# 17       49000      157175              44
# 18       51100      179380              47
# 19       54100      104260              15
# 20       57070      120874              42
# 21       59260      236710              35
# 22       63100      147327              43
# 23       66000      119656              68
# 24       67000      291313              78
# 25       68200      106341              22
# 26       69000      522250              48
# 27       69100      156928              15
# 28       72100      145004              53
# 29       74000      131715              16
# 30       75000     2133111             105
# 31       76620      166058              55
# 32       76100      114083              21
# 33       80090      133625              50
# 34       83000      180452              44
# 35       87100      129760              80
# 36       92100      119808               6
# 37       93100      111455               9
# 38       93210      113942              12
# 39       95100      107221              17
# 40       97400      154765             142
# 41       97411      105240             240

# %%
dtypes = {
    'dep_code': str,
    'code_postal': str
}
df_cities = pd.read_json('data/villes100k.json', encoding='UTF-8', orient='records', dtype=dtypes)
df_cities
# Out:
#             nom_standard       nom_sans_pronom dep_code              dep_nom  \
# 0                   Nice                  Nice       06      Alpes-Maritimes
# 1        Aix-en-Provence       Aix-en-Provence       13     Bouches-du-Rhône
# 2              Marseille             Marseille       13     Bouches-du-Rhône
# 3                   Caen                  Caen       14             Calvados
# 4                  Dijon                 Dijon       21            Côte-d'Or
# 5               Besançon              Besançon       25                Doubs
# 6                  Brest                 Brest       29            Finistère
# 7                  Nîmes                 Nîmes       30                 Gard
# 8               Toulouse              Toulouse       31        Haute-Garonne
# 9               Bordeaux              Bordeaux       33              Gironde
# 10           Montpellier           Montpellier       34              Hérault
# 11                Rennes                Rennes       35      Ille-et-Vilaine
# 12                 Tours                 Tours       37       Indre-et-Loire
# 13              Grenoble              Grenoble       38                Isère
# 14         Saint-Étienne         Saint-Étienne       42                Loire
# 15                Nantes                Nantes       44     Loire-Atlantique
# 16               Orléans               Orléans       45               Loiret
# 17                Angers                Angers       49       Maine-et-Loire
# 18                 Reims                 Reims       51                Marne
# 19                 Nancy                 Nancy       54   Meurthe-et-Moselle
# 20                  Metz                  Metz       57              Moselle
# 21                 Lille                 Lille       59                 Nord
# 22      Clermont-Ferrand      Clermont-Ferrand       63          Puy-de-Dôme
# 23             Perpignan             Perpignan       66  Pyrénées-Orientales
# 24            Strasbourg            Strasbourg       67             Bas-Rhin
# 25              Mulhouse              Mulhouse       68            Haut-Rhin
# 26                  Lyon                  Lyon       69                Rhône
# 27          Villeurbanne          Villeurbanne       69                Rhône
# 28               Le Mans                  Mans       72               Sarthe
# 29                Annecy                Annecy       74         Haute-Savoie
# 30                 Paris                 Paris       75                Paris
# 31              Le Havre                 Havre       76       Seine-Maritime
# 32                 Rouen                 Rouen       76       Seine-Maritime
# 33                Amiens                Amiens       80                Somme
# 34                Toulon                Toulon       83                  Var
# 35               Limoges               Limoges       87         Haute-Vienne
# 36  Boulogne-Billancourt  Boulogne-Billancourt       92       Hauts-de-Seine
# 37             Montreuil             Montreuil       93    Seine-Saint-Denis
# 38           Saint-Denis           Saint-Denis       93    Seine-Saint-Denis
# 39            Argenteuil            Argenteuil       95           Val-d'Oise
# 40           Saint-Denis           Saint-Denis      974           La Réunion
# 41            Saint-Paul            Saint-Paul      974           La Réunion
#
#    code_postal  population  superficie_km2
# 0        06000      348085              74
# 1        13100      147478             188
# 2        13000      873076             241
# 3        14000      108200              26
# 4        21000      159346              42
# 5        25000      119198              65
# 6        29200      139619              49
# 7        30900      148104             161
# 8        31100      504078             118
# 9        33300      261804              50
# 10       34080      302454              57
# 11       35700      225081              50
# 12       37100      137658              33
# 13       38000      157477              19
# 14       42100      172718              80
# 15       44200      323204              66
# 16       45000      116617              28
# 17       49000      157175              44
# 18       51100      179380              47
# 19       54100      104260              15
# 20       57070      120874              42
# 21       59260      236710              35
# 22       63100      147327              43
# 23       66000      119656              68
# 24       67000      291313              78
# 25       68200      106341              22
# 26       69000      522250              48
# 27       69100      156928              15
# 28       72100      145004              53
# 29       74000      131715              16
# 30       75000     2133111             105
# 31       76620      166058              55
# 32       76100      114083              21
# 33       80090      133625              50
# 34       83000      180452              44
# 35       87100      129760              80
# 36       92100      119808               6
# 37       93100      111455               9
# 38       93210      113942              12
# 39       95100      107221              17
# 40       97400      154765             142
# 41       97411      105240             240

# %%
df_cities.population.sum()
# Out:
# np.int64(10232650)
