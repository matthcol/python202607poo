# %% [markdown]
# # Python
# Apprendre Python avec un notebook, c'est plus interactif.

# %% [markdown]
# ## Exemple Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.normal(10.0, 2.5, 1_000_000)
data
# Out:
# array([12.07844993, 12.07261979,  9.15112631, ..., 10.14027047,
#         9.7698827 , 15.38260269], shape=(1000000,))

# %%
_ = plt.hist(data, bins=1000)

# %%
data.mean(), data.std()
# Out:
# (np.float64(10.00270276207829), np.float64(2.5004889562867776))

# %% [markdown]
# ## Données Builtins
# Simples:
# - float
# - int
# - complex
# - str (Unicode)
# - bool
# - bytes
# - None
#
# Conteneurs:
# - list, tuple
# - dict
# - set

# %%
x = 1E308
x, 2*x, type(x)
# Out:
# (1e+308, inf, float)

# %%
nb = 
nb * 2
# Out:
# 

# %%
city1 = "L'Haÿ-les-Roses"
word_fr = "cœur"
city2 = "東京"
sentence = f"I ❤️ both {city1} and {city2} with all my {word_fr}"  # f-string
sentence
# Out:
# "I ❤️ both L'Haÿ-les-Roses and 東京 with all my cœur"

# %%
len(city2) == 2
# Out:
# True

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# ### Fonctions natives

# %%
print(city2) # calls str
city2  # calls repr
# Out:
# 東京
# '東京'

# %%
print(data)
data
# Out:
# [6.79155813 9.57909035 8.48426952 ... 8.66650619 8.42640185 8.56649916]
# 1000000

# %%
print(str(city2))
print(repr(city2))
# Out:
# 東京
# '東京'

# %%
print(len(city1))
print(len(data))
# print(len(None)) # TypeError: object of type 'NoneType' has no len()
# print(len(x)) # TypeError: object of type 'float' has no len()
# print(len(nb)) # TypeError: object of type 'int' has no len()
# Out:
# 15
# 1000000

# %%
print(bool(None))
print(not None)
print(None or True)
print(bool(city2))
print(bool(""))
print(bool(0))
print(bool([]))
# Out:
# False
# True
# True
# True
# False
# False
# False

# %%
nb_text = "123"
nb = int(nb_text) # base=10 par défaut
nb
# Out:
# 123

# %%
nb_text = "aa12ffbc"
nb = int(nb_text, base=16)
nb
# Out:
# 2853371836

# %%
int(nb_text, 16)
# Out:
# 2853371836

# %%
# TypeError: 'x' is an invalid keyword argument for int()
# int(x=nb_text, base=16)

# %%
print(city1, city2, word_fr)
print()
print(city1, city2, word_fr, sep=", ")
print(city1, city2, sep=" -> ", end=". ")
print("Arrêt pour manger.")
# Out:
# L'Haÿ-les-Roses 東京 cœur
#
# L'Haÿ-les-Roses, 東京, cœur
# L'Haÿ-les-Roses -> 東京. Arrêt pour manger.

# %%
sep = " -> "
print(city1, city2, sep=sep)
print(city1.upper(), city2.upper(), sep=sep)
# Out:
# L'Haÿ-les-Roses -> 東京
# L'HAŸ-LES-ROSES -> 東京

# %% [markdown]
# ### Conteneurs
# Builtin collections:
# - list: [v1, v2], en général homogène (car modifiable)
# - tuple: (v1, v2) ou sans v1, v2 ; non modifiable (peut être hétérogène)
# - dict: {k1: v1, k2: v2}
# - set: {v1, v2}

# %%
cities = [
# cities: list[str] = [
    'Toulouse',
    'Bordeaux', 
    'Hanoï',
    'Pibrac',
    'Saillagouse', 
    'Belfast',
    'Crampagna',
    'New-York',
    'Pau'
]

# %%
type(cities), len(cities)
# Out:
# (list, 9)

# %%
# list_city_pop: list[tuple[str, int]] = [
list_city_pop = [
    ('Toulouse', 500_000),
    ('Bordeaux', 300_000), 
    ('Hanoï', 9_000_000),
    ('Pibrac',7_000),
    ('Saillagouse', 1_200), 
    ('Belfast', 640_000),
    ('Crampagna', 110),
    ('New-York', 20_000_000),
    ('Pau', 77_000)
]

# %%
print(cities[0]) # 1er
print(cities[-1]) # dernier, i.e. len() - 1
# print(cities[9]) # IndexError: list index out of range

print(list_city_pop[0])
print(list_city_pop[-1])

print(list_city_pop[0][0])
# Out:
# Toulouse
# Pau
# ('Toulouse', 500000)
# ('Pau', 77000)
# Toulouse

# %%
city2[0]
# Out:
# '東'

# %%
# city2[0] = 'A' # TypeError: 'str' object does not support item assignment
# list_city_pop[0][1] += 1 # TypeError: 'tuple' object does not support item assignment
list_city_pop[0] = (list_city_pop[0][0], list_city_pop[0][1] + 1)
list_city_pop[0]
# Out:
# ('Toulouse', 500001)

# %%
def incr_city(list_city_pop: list[tuple[str, int]], index: int, delta: int) -> None:
    name, pop = list_city_pop[index]
    list_city_pop[index] = (name, pop + delta)

# %%
r = incr_city(list_city_pop, 0, 10_523)
assert r is None
list_city_pop[0]
# Out:
# ('Toulouse', 510524)

# %%
cities.append('Paris')
cities.extend(['Marseille', 'Lille'])
# cities.extend('Tours') # Attention ! ajoute les lettres 1 à 1
cities
# Out:
# ['Toulouse',
#  'Bordeaux',
#  'Hanoï',
#  'Pibrac',
#  'Saillagouse',
#  'Belfast',
#  'Crampagna',
#  'New-York',
#  'Pau',
#  'Paris',
#  'Marseille',
#  'Lille',
#  'Tours']

# %%
print(city1[:5])  # 5 premiers: de l'index 0 à 4
print(city1[5:10])
print(city1[10:])

print(city1[-5:]) # 5 derniers
# Out:
# L'Haÿ
# -les-
# Roses
# Roses

# %%
print(cities[3])
print(cities[3][-5:])
# Out:
# Pibrac
# ibrac

# %%
print(cities[100:])
# Out:
# []

# %%
data[::10_000]
# Out:
# array([ 6.79155813,  9.58342432,  8.75816741,  9.21855375,  9.30193566,
#        10.56027614,  8.81451562,  9.76845034, 12.0295121 , 10.61134131,
#         9.97494606,  6.14355002,  9.8360668 ,  6.08420697, 11.23332227,
#        12.15845662,  9.19073099, 11.37016635,  6.57020503,  8.05731131,
#         9.61936064,  7.7614859 , 10.83978068,  7.50252282, 14.40907959,
#        12.91306267, 15.48004875,  7.99917954, 10.87095645, 11.276961  ,
#        13.45889338,  9.25015841, 17.26039015,  9.74777142,  4.46439741,
#        11.10091605,  7.04821171,  9.82924256, 12.79687174, 10.8611431 ,
#        12.16759044, 11.1716975 ,  6.65290543,  7.69134177,  9.35121229,
#         7.93227774,  7.49934125, 12.04674943, 11.3078366 ,  7.26399989,
#        11.09838336,  5.19933513,  9.58084034,  9.36173668,  6.14344228,
#         9.9835538 , 10.03008528,  7.27121357,  7.761545  ,  7.17908724,
#         6.41989628, 10.54464413,  8.04059552,  6.78897701, 15.67936766,
#        13.07786959,  9.20166561,  9.59903634, 11.79036653,  9.44712053,
#         9.57884065,  8.00035763, 11.84803175, 10.7681254 , 12.99190726,
#        11.07426118, 10.71917164,  8.02619326, 15.18239199,  6.6233303 ,
#        11.07084038, 14.12701274,  9.78483582, 13.82043426, 11.49094261,
#        11.24969304, 11.70805651,  9.45127092, 12.54810697,  9.44772214,
#        11.04481991,  8.59846418,  9.61825617,  9.13856981,  9.37960058,
#         8.48324388, 13.74732586, 10.95752936, 13.51238759, 11.44168254])

# %%
city1[::-1]
# Out:
# "sesoR-sel-ÿaH'L"

# %%
def is_palindrome(word: str) -> bool:
    return word.lower() == word[::-1].lower()

# %%
assert is_palindrome('kayak')
assert is_palindrome('Kayak')
assert not is_palindrome(city1)

# %%
print(len(city1))
print(len(cities))
print(len(list_city_pop[0]))
print(len(list_city_pop[0][0]))
# print(len(list_city_pop[0][1])) #TypeError: object of type 'int' has no len()
# Out:
# 15
# 13
# 2
# 8

# %%
print(list_city_pop[0])
print(list_city_pop[0][0])
print(list_city_pop[0][0][2])
# Out:
# ('Toulouse', 510524)
# Toulouse
# u

# %%
for city in cities:
    print(city)
# Out:
# Toulouse
# Bordeaux
# Hanoï
# Pibrac
# Saillagouse
# Belfast
# Crampagna
# New-York
# Pau
# Paris
# Marseille
# Lille
# Tours

# %%
# TypeError: 'int' object is not iterable
# for digit in nb:
    # print(digit)

# %%
for l in city1:
    print(l, l.upper(), sep=' -> ')
# Out:
# L -> L
# ' -> '
# H -> H
# a -> A
# ÿ -> Ÿ
# - -> -
# l -> L
# e -> E
# s -> S
# - -> -
# R -> R
# o -> O
# s -> S
# e -> E
# s -> S

# %%
for i in range(len(cities)):
    city = cities[i]
    print(i, city)
# Out:
# 0 Toulouse
# 1 Bordeaux
# 2 Hanoï
# 3 Pibrac
# 4 Saillagouse
# 5 Belfast
# 6 Crampagna
# 7 New-York
# 8 Pau
# 9 Paris
# 10 Marseille
# 11 Lille
# 12 Tours

# %%
for i, city in enumerate(cities):
    print(f"{i} - {city}")
# Out:
# 0 - Toulouse
# 1 - Bordeaux
# 2 - Hanoï
# 3 - Pibrac
# 4 - Saillagouse
# 5 - Belfast
# 6 - Crampagna
# 7 - New-York
# 8 - Pau
# 9 - Paris
# 10 - Marseille
# 11 - Lille
# 12 - Tours

# %%
for i, city in enumerate(cities, start=1):
    print(f"{i:02d} - {city}")
# Out:
# 01 - Toulouse
# 02 - Bordeaux
# 03 - Hanoï
# 04 - Pibrac
# 05 - Saillagouse
# 06 - Belfast
# 07 - Crampagna
# 08 - New-York
# 09 - Pau
# 10 - Paris
# 11 - Marseille
# 12 - Lille
# 13 - Tours

# %% [markdown]
# ### Exercice: les villes qui comment par B

# %%
for city in cities:
    if city.strip().lower().startswith('b'):
        print(city)
# Out:
# Bordeaux
# Belfast

# %%
cities_b = []
for city in cities:
    if city.strip().lower().startswith('b'):
        cities_b.append(city)
cities_b
# Out:
# ['Bordeaux', 'Belfast']

# %%
cities.extend(['bruxelles', '  bourges ', '\tblagnac\t\t\n\r'])

# %%
[city for city in cities if city.strip().lower().startswith('b')]
# Out:
# ['Bordeaux', 'Belfast', 'bruxelles', '  bourges ', '\tblagnac\t\t\n\r']

# %%
[city.strip().lower() for city in cities]
# Out:
# ['toulouse',
#  'bordeaux',
#  'hanoï',
#  'pibrac',
#  'saillagouse',
#  'belfast',
#  'crampagna',
#  'new-york',
#  'pau',
#  'paris',
#  'marseille',
#  'lille',
#  'tours',
#  'bruxelles',
#  'bourges',
#  'blagnac']

# %%
cities_filtered = [
    city_n for city_n in (
        city.strip().lower() for city in cities
    ) if city_n.startswith('b')
]
cities_filtered
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
numbers = [12, 23, 67, 43]
[n**2 + 1 for n in numbers]
# Out:
# [145, 530, 4490, 1850]

# %%
[n**2 + 1 for n in numbers if n % 2 == 1]
# Out:
# [530, 4490, 1850]

# %%
g = (n**2 + 1 for n in numbers if n % 2 == 1)
g
# Out:
# <generator object <genexpr> at 0x00000255FFB2DB10>

# %%
sum(g)
# Out:
# 6870

# %%
list(
    filter(
        lambda city_n: city_n.startswith('b'),
        map(
            lambda city: city.strip().lower(),
            cities
        )
    )
)
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
cities_b = []
for city in cities:
    city_n = city.strip().lower()
    if city_n.startswith('b'):
        cities_b.append(city_n)
cities_b
# Out:
# ['bordeaux', 'belfast', 'bruxelles', 'bourges', 'blagnac']

# %%
f = 'λ x: x**2 + 1'
f
# Out:
# 'λ x: x**2 + 1'

# %%
f2 = f.replace('λ', 'lambda')
f2
# Out:
# 'lambda x: x**2 + 1'

# %%
f3 = eval(f2)
f3
# Out:
# <function __main__.<lambda>(x)>

# %%
f3(3)
# Out:
# 10
